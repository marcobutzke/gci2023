# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
cidades = pd.read_excel('BRCidadesRegiao.xlsx')
cidades
# Out:
#       Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1              municipio   codigo  \
# 0                0           0             0             Açailândia  2100055
# 1                1           1             1           Afonso Cunha  2100105
# 2                2           2             2  Água Doce do Maranhão  2100154
# 3                3           3             3              Alcântara  2100204
# 4                4           4             4          Aldeias Altas  2100303
# ...            ...         ...           ...                    ...      ...
# 5531          5531        5531          5955              Pacaraima  1400456
# 5532          5532        5532          5956           Rorainópolis  1400472
# 5533          5533        5533          5957     São João da Baliza  1400506
# 5534          5534        5534          5958               São Luiz  1400605
# 5535          5535        5535          5959               Uiramutã  1400704
#
# ...

# %%
cidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5536 entries, 0 to 5535
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.2             5536 non-null   int64
#  1   Unnamed: 0               5536 non-null   int64
#  2   Unnamed: 0.1             5536 non-null   int64
#  3   municipio                5536 non-null   object
#  4   codigo                   5536 non-null   int64
#  5   area_territorial         5536 non-null   float64
#  6   populacao_estimada       5536 non-null   int64
#  7   densidade_demografica    5531 non-null   float64
#  8   escolarizacao            5531 non-null   float64
#  9   idhm                     5531 non-null   float64
#  10  mortalidade_infantil     1574 non-null   float64
#  11  pib_per_capita           5536 non-null   float64
#  12  uf                       5536 non-null   object
#  13  receitas_realizadas      5514 non-null   float64
# ...

# %%
vif_dt = cidades[['area_territorial', 'populacao_estimada', 'densidade_demografica', 'escolarizacao',
'idhm', 'pib_per_capita']]

# %%
vif_dt
# Out:
#       area_territorial  populacao_estimada  densidade_demografica  \
# 0             5808.304              113121                  17.92
# 1              371.338                6578                  15.90
# 2              443.267               12652                  26.13
# 3             1168.246               22112                  14.70
# 4             1942.121               26757                  12.33
# ...                ...                 ...                    ...
# 5531          8025.045               18913                   1.30
# 5532         33579.739               30782                   0.72
# 5533          4284.505                8348                   1.58
# 5534          1526.898                8110                   4.42
# 5535          8113.598               10789                   1.04
#
#       escolarizacao   idhm  pib_per_capita
# 0              97.7  0.672        19780.01
# 1              96.6  0.529         6934.67
# ...

# %%
# Replace infinite updated data with nan
vif_dt.replace([np.inf, -np.inf], np.nan, inplace=True)
# Drop rows with NaN
vif_dt.dropna(inplace=True)
print(vif_dt)
# Out:
#       area_territorial  populacao_estimada  densidade_demografica  \
# 0             5808.304              113121                  17.92
# 1              371.338                6578                  15.90
# 2              443.267               12652                  26.13
# 3             1168.246               22112                  14.70
# 4             1942.121               26757                  12.33
# ...                ...                 ...                    ...
# 5531          8025.045               18913                   1.30
# 5532         33579.739               30782                   0.72
# 5533          4284.505                8348                   1.58
# 5534          1526.898                8110                   4.42
# 5535          8113.598               10789                   1.04
#
#       escolarizacao   idhm  pib_per_capita
# 0              97.7  0.672        19780.01
# 1              96.6  0.529         6934.67
# ...

# %%
# vif = data[['area', 'densidade', 'idh', 'populacao', 'rendimento']]
vif_data = pd.DataFrame()
vif_data['variavel'] = vif_dt.columns
vif_data['VIF'] = [variance_inflation_factor(vif_dt.values, i) 
    for i in range(len(vif_dt.columns))]
vif_data
# Out:
#                 variavel         VIF
# 0       area_territorial    1.071160
# 1     populacao_estimada    1.287414
# 2  densidade_demografica    1.311548
# 3          escolarizacao  118.578969
# 4                   idhm  131.393449
# 5         pib_per_capita    2.781086
